# %% [markdown]
# # q3dfit example notebook: rest-frame mid-IR, MIRI MRS data of NGC 7469

# %% [markdown]
# <h3><font color='teal'>Installation of the environment and the package are described <a href="https://q3dfit.readthedocs.io/">here</a>. </font></h3>

# %% [markdown]
# This Jupyter notebook allows you to run Q3Dfit, a PSF decomposition and spectral analysis package tailored for JWST NIRSpec and MIRI IFU observations.
#
# Q3Dfit is developed as a science-enabling data product by the Early Release Science Team #1335 Q3D. You can find more information about this ERS program **Q3D** [here](https://wwwstaff.ari.uni-heidelberg.de/dwylezalek/q3d.html) and [here](https://www.stsci.edu/jwst/science-execution/approved-programs/dd-ers/program-1335).
#
# The software is based on the existing package IFSFIT developed by Dave Rupke (see [ADS link](https://ui.adsabs.harvard.edu/abs/2017ApJ...850...40R/abstract)).
#
# The following notebook will guide you through the initialization procedure and will then perform the analysis.

# %% [markdown]
# ## Table of Contents
#
# * [1. Initialization](#chapter1)
#     * [1.0. Setting up the directory tree](#chapter1_0)
#     * [1.1. Setting up the data and models](#chapter1_1)
#     * [1.2. Setting up the fitting parameters](#chapter1_2)
#         * [1.2.1. Emission line parameters](#chapter1_2_1)
#         * [1.2.2. Continuum parameters](#chapter1_2_2)
#     * [1.3. Setting up the plotting parameters](#chapter1_3)
# * [2. Run fitting and plotting routines](#chapter2)

# %% [markdown]
# ## 1. Initialization <a class="anchor" id="chapter1"></a>

# %%
import os.path
import numpy as np
# %matplotlib inline
# unless you are running this python notebook from the directory where q3dfit is installed, you need to point the
# path to the package in order to import it. 
import sys
sys.path.append("/home/jovyan") # for JWebbinar
sys.path.append("../")

# %%
# if QUESTFIT is needed, in mid-IR
from q3dfit.questfit_readcf import readcf

# %%
# Convenience function
# Ref: https://github.com/spacetelescope/jwebbinar_prep/blob/main/imaging_mode/imaging_mode_stage_1.ipynb
from astropy.utils.data import download_file
def download_files(files, output_directory, force=False):
    """Given a tuple or list of tuples containing (URL, filename),
    download the given files into the current working directory.
    Downloading is done via astropy's download_file. A symbolic link
    is created in the specified output dirctory that points to the
    downloaded file.
    
    Parameters
    ----------
    files : tuple or list of tuples
        Each 2-tuple should contain (URL, filename), where
        URL is the URL from which to download the file, and
        filename will be the name of the symlink pointing to
        the downloaded file.
        
    output_directory : str
        Name of the directory in which to create the symbolic
        links to the downloaded files
        
    force : bool
        If True, the file will be downloaded regarless of whether
        it is already present or not.
                
    Returns
    -------
    filenames : list
        List of filenames corresponding to the symbolic links
        of the downloaded files
    """
    # In the case of a single input tuple, make it a
    # 1 element list, for consistency.
    filenames = []
    if isinstance(files, tuple):
        files = [files]
        
    for file in files:
        filenames.append(file[1])
        if force:
            print('Downloading {}...'.format(file[1]))
            demo_file = download_file(file[0], cache='update')
            # Make a symbolic link using a local name for convenience
            if not os.path.islink(os.path.join(output_directory, file[1])):
                os.symlink(demo_file, os.path.join(output_directory, file[1]))
        else:
            if not os.path.isfile(os.path.join(output_directory, file[1])):
                print('Downloading {}...'.format(file[1]))
                demo_file = download_file(file[0], cache=True)
                # Make a symbolic link using a local name for convenience
                os.symlink(demo_file, os.path.join(output_directory, file[1]))
            else:
                print('{} already exists, skipping download...'.format(file[1]))
                continue
    return filenames

# %% [markdown]
# ### 1.0. Setting up the directory tree <a class="anchor" id="chapter1_0"></a>
#
# Define the directories in which the data cube(s) that you want to analyse are stored and the output directories. We recommend creating a working directory that you name after your target, in which all outputs from q3dfit will be saved. Then download test data.

# %%
# Base directory (book-keeping)
volume = 'NGC7469/'
# prefix label for output files
gal = 'NGC7469'
# Input directory
indir = volume
if not os.path.exists(indir):
    os.makedirs(indir)
# Output directory
outdir = volume
if not os.path.exists(outdir):
    os.makedirs(outdir)
# Initialization file (q3di.npy) directory
initdir = volume
# Output logfile
logfile = outdir+gal+'-fitlog.txt'

# %% [markdown]
# Download data from public Box folder. <font color='red'> Note: This also downloads the *.cf configuration file (specifying which spectral components to include in the MIR fitting). We note that the format of this file is currently under development and it will in the future be superseded by a more readable/convenient option. For a current description of continuum fitting parameters in the .cf file, please see the documentation:
# https://q3dfit.readthedocs.io/en/latest/

# %%
# make tuples of urls and download filenames
# infile = data cube
# cf = config file
#infile_tup = ('https://rhodes.box.com/shared/static/spe9pc4kbwylw2khwcca0cimoaks6puh.fits', '22128896_mock_cube.fits')
infile_tup = ('https://rhodes.box.com/shared/static/dyyf2s8do67w4md67yrit0o8vy94n7ao.fits', 'jw01328-o016_t011_miri_ch2-shortmediumlong-_s3d.fits')
infile_tup = ('https://rhodes.box.com/shared/static/xv95lxg9qzxg27f7xs9feid3xzvtla3q.fits', 'jw01328-o015_t014_miri_ch2-mediumshortlong-_s3d.fits')
#cf_tup = ('https://rhodes.box.com/shared/static/6502fu97kxwky9zl5t2t8gnn6n2fi2y9.cf', '22128896.cf')
cf_tup = ('https://rhodes.box.com/shared/static/3ndd14t8kr9h3yabwt0p3p6td1zsf3yv.cf', 'NGC7469.cf')
# download files; by default don't force overwrite and take first element of output
infile = download_files(infile_tup, indir, force=False)[0]
cfinfile = download_files(cf_tup, indir, force=False)[0]
# add subdirectory to filenames
infile = indir+infile
cfinfile = indir+cfinfile
# Out:
# jw01328-o015_t014_miri_ch2-mediumshortlong-_s3d.fits already exists, skipping download...
# NGC7469.cf already exists, skipping download...

# %% [markdown]
# ### 1.1. Setting up the data and models <a class="anchor" id="chapter1_1"></a>
#
# Some general information about your cube. `argsreadcube` is a dictionary of attributes sent to the `CUBE` class.
# - For non-JWST data, set `wmapext` to `None`. The WMAP extension is a [3-D weight image](https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/science_products.html) giving the relative weights of the output spaxels.
# - Microns are the wavelength unit used internally, but `q3dfit` can accept other wavelength input units or output other units.
# - The code does calculations in flambda space, but assumes input units of MJy/sr, the JWST default. Other input wavelength units can be specified.

# %% [markdown]
# Some general information about your cube:

# %%
from q3dfit.readcube import Cube
from astropy.io import fits

hdul = fits.open(infile)

#argsreadcube = {'wmapext': None,
#                'wavext': 4,
#                'waveunit_in': 'Angstrom',
#                'fluxunit_in': 'Jy'}
argsreadcube = {'wmapext':4, 'datext': 1, 'varext': 2, 'dqext': 3, 
                'fluxnorm': 1e-14, #1e-8, 
                'pixarea_sqas': hdul[1].header['PIXAR_A2'], #0.0025,
                #'fluxunit_in': 'Jy', 
                'fluxunit_in':'MJy/sr', 'waveunit_in': 'micron'}

if not os.path.isfile(infile): 
    print('Data cube not found.')
else:
    cube = Cube(infile, **argsreadcube)
    ncols = cube.ncols # number of columns
    nrows = cube.nrows # number of rows
    cube.about()

if not os.path.isfile(cfinfile):
    print('Configuration file not found.')
else:
    config_file = readcf(cfinfile)
# Out:
# Size of data cube: [ 45 , 41 , 2100 ]
# Wavelength range: [ 7.511000228929333 , 11.709000428323634 ]  micron

# %% [markdown]
# Name and systemic redshift of the galaxy. `zsys` is presently not used within the code, but would be an input for, e.g., calculating velocity maps in routines under development (e.g., `makemaps.py`). It is used in this notebook in initializing the arrays of initial guesses below.

# %%
name = 'NGC7469'
zsys_gas = 0.0

# %% [markdown]
# Wavelength range over which to fit data. The user can also specify sets of regions to ignore in the fit.

# %%
fitrange = np.array([7.515, 11.7])  # micron

# %% [markdown]
# Create quasar template from the central spaxel of the spatially-unbinned data cube.

# %%
from q3dfit.makeqsotemplate import makeqsotemplate
#makeqsotemplate(infile, outdir+'miritest.npy', wmapext=None)
makeqsotemplate(infile, outdir+'NGC7469_qso.npy', argscube=argsreadcube)
makeqsotemplate(infile, '../q3dfit/data/questfit_templates/'+'NGC7469_qso.npy', argscube=argsreadcube)
qsotemplate = outdir+'NGC7469_qso.npy'

# %% [markdown]
# ### 1.2. Setting up the fitting parameters<a class="anchor" id="chapter1_2"></a>

# %% [markdown]
# #### 1.2.1. Emission-line parameters <a class="anchor" id="chapter1_2_1"></a>

# %% [markdown]
# What lines do you want to fit? You can choose from the linelists [here](https://github.com/Q3D/q3dfit/tree/main/data/linelists), or in `q3dfit/data/linelists/`.

# %%
lines = ['H2_00_S5', '[ArII]6.99', '[ArIII]8.99', '[NeII]12.81', 
         '[NeIII]15.56', 'H2_00_S3', 'H2_00_S1', '[SIII]18.71']

# %% [markdown]
# How many components do you want to be fitted to the emission lines?

# %%
maxncomp = 1

# %% [markdown]
# This block sets up initial conditions for the emission-line fit to each spaxel. Emission lines are set to a common redshift and velocity dispersion. However, different sets of emission lines can have different velocities and linewidths by specifying different lines to which to tie particular emission lines.

# %%
linetie = dict()
ncomp = dict()
zinit_gas = dict()
siginit_gas = dict()
for i in lines:
    linetie[i] = '[NeII]12.81'
    ncomp[i] = np.full((ncols,nrows),maxncomp)
    zinit_gas[i] = np.full((ncols,nrows,maxncomp),0.)
    siginit_gas[i] = np.full((ncols,nrows,maxncomp), 1000.)

# %% [markdown]
# `siglim_gas` sets lower and upper bounds for the Gaussian width (sigma) of the emission line. These limits can be set globablly, for all spaxels and components, by defining a 2-element array. The limits can also be set for individual spaxels (but all components) by defining an (Ncol x Nrow x 2) array.

# %%
siglim_gas = np.array([5., 4000.])

# %% [markdown]
# #### Spectral resolution convolution
# ##### Just running convolution ---
#
# If no convolution is desired, then set `spectres_convolve` to None.
# If convolution is desired, then `spectres_convolve` and `spect_instrum` are required variables.
#
# Specify the desired convolution method using `spect_instrum`. The syntax is:
# `spect_instrum = {INSTRUMENT:[METHOD]}`, which should mirror the filename in `q3dfit/data/dispersion_files/`. METHOD specifies the grating, spectral resolution [R], Δλ FWHM in [Å], velocity in [km/s].
#
# Examples convolving with:
# 1. flat R=500: `spect_instrum = {'flat':['R500']}`
# 2. flat velocity FWHM = 30km/s: `spect_instrum = {'flat':['kms30']}`
# 3. flat Δλ FWHM = 4 Å: `spect_instrum = {'flat':['dlambda4']}`
# 4. JWST NIRSPEC / G140M: `spect_instrum = {'JWST_NIRSPEC':['G140M']}`
#
# If desired flat convolution file does not exist, then a new file will be created automatically.

# %%
#spect_instrum = {'spitzer_irs_ch0':['sl2','sl1',],'spitzer_irs_ch2':['ll1','ll2']}
#spectres_convolve = {'ws_instrum':spect_instrum}
spect_instrum = {'JWST_MIRI':['CH2A']}
spectres_convolve = {'ws_instrum':spect_instrum}

# %% [markdown]
# ##### Creating convolution files (optional) ---
#
# If the user wants to create a dispersion file, there are 2 methods:
#
# 1. First, run `from q3dfit.spectConvol import dispFile` and initialize: `dispObj = dispFile()`
# 2. Create the files with either method A or B
#
# 2.(A) Create a flat R=120 dispersion file from 10 μm to 30 μm:
#
# `dispObj.make_dispersion(120,WAVELEN=[10,30],TYPE='R')`
#
# 2.(B) Create a custom dispersion file with user supplied wavelength and Resolving power lists:
#
# `dispObj.make_custom_dispersion([wavelen list],R=[some R list],FILENAME='custom_RlistA_disp')`
#
# 3. Specify desired dispersion file in convolution: running custom example 2B
#
# `spect_instrum = {'custom':['RlistA']}`

# %%
#from q3dfit.spectConvol import dispFile
#dobj = dispFile()
#dispObj.make_custom_dispersion([wavelen list],R=[some R list],FILENAME='custom_RlistA_disp')
#spect_instrum = {'custom':['RlistA']}

# %% [markdown]
# #### 1.2.2 Continuum parameters <a class="anchor" id="chapter1_2_2"></a>

# %% [markdown]
# `q3dfit` first masks emission lines before fitting. This sets is the default mask value in km/s for each velocity component for the first fit. During the second fit, the mask value is set automatically using the best-fit linewidths determined from the first fit.

# %%
maskwidths_def = 1000.

# %% [markdown]
# The continuum fitting parameters specified here are for the case of general MIR fitting.

# %%
fcncontfit = 'questfit'
argscontfit = dict()
argscontfit['config_file'] = cfinfile
argscontfit['outdir'] = outdir
argscontfit['plot_decomp'] = True

# %% [markdown]
# The mid-IR continuum fitting includes features that depend on redshift. These are specified as "stellar" redshift for compatibility with stellar template fitting, even though they refer in this case to the redshift of the mid-IR dust features. The input spectrum has in this case already been shifted to rest wavelengths.

# %%
zinit_stars = np.full((ncols,nrows),0.0)

# %% [markdown]
# ### 1.3. Setting up the plotting and output parameters <a class="anchor" id="chapter1_3"></a>

# %% [markdown]
# One dictionary must be defined for a line plot to appear. `argspltlin1` holds the options for the first line plot, and `argspltlin2` is for the second. Parameter options are fed in as keyword/data pairs.
#
# Required keywords in each dictionary:
# * `nx`: Number of subplots in the horizontal direction
# * `ny`: Number of subplots in the vertical direction
# * Options for centerting the plot:
#     - `line`: a string list of line labels
#     - `center_obs`: a float list of wavelengths of each subplot center, in the observed (plotted) frame
#     - `center_rest`: a float list of wavelengths of each subplot center, in the rest frame, which are converted to obs. frame
#
# Optional keywords:
# * `size`: float list of widths in wavelength space of each subplot; if not specified, default is 300 $Å$
# * `IR`: set to `True` to use infrared-style plot

# %%
argspltlin1 = {'nx': 3,
               'ny': 2,
               'line': ['[ArII]6.99', '[ArIII]8.99', '[NeII]12.81', 
                        '[NeIII]15.56', 'H2_00_S1', '[SIII]18.71'],
               'size': [3., 3., 3., 3., 3., 3.],
               'IR': True}

# %% [markdown]
# Set this input to `q3da` to specify that the quasar and host contributions should be separated in the output files.

# %%
decompose_qso_fit = True

# %% [markdown]
# The following cell will create the initialisation structure. **Do not change anything in this cell.**

# %%
q3di = { # Required pars
        'fcninitpar': 'parinit',
        'fitran': fitrange,
        'infile': infile,
        'label': config_file['source'][0].replace('.ideos','').replace('.npy', ''),
        'lines': lines,
        'linetie': linetie,
        'maxncomp': maxncomp,
        'ncomp': ncomp,
        'outdir': outdir,
        'zinit_stars': zinit_stars,
        'zinit_gas': zinit_gas,
        'zsys_gas': zsys_gas,
        # Optional pars
        'argsreadcube': argsreadcube,
        'argscontfit': argscontfit,
        'argspltlin1': argspltlin1,
        'decompose_qso_fit': decompose_qso_fit,
        'fcncheckcomp': 'checkcomp',
        'fcncontfit': fcncontfit,            
        'logfile': logfile,
        'maskwidths_def': maskwidths_def,
        'siglim_gas': siglim_gas,
        'siginit_gas': siginit_gas,
        'spect_convol':spectres_convolve
       }

# %% [markdown]
# If you want to run `q3dfit` in batch mode, run this cell, which saves q3di to an `npy` file. In your python command line, read in file and run `q3dfit` with
# <pre><code>q3di = '/path/to/the/npy/file/q3di.npy'
# from q3dfit.q3df import q3df
# q3df(q3di,cols=cols,rows=rows)</code></pre>

# %%
q3di_npy = 'q3di.npy'
np.save(initdir+q3di_npy,q3di)

# %% [markdown]
# ## 2. Run fitting and plotting routines <a class="anchor" id="chapter2"></a>

# %%
from q3dfit.q3df import q3df
from q3dfit.q3da import q3da

# %% [markdown]
# Choose columns and rows to fit. Ranges are specified as two-element lists specifying the first and last spaxel.

# %%
cols = 20
rows = 20

# %% [markdown]
# Run the fit. Choose `quiet=False` for verbose output. An output dictionary for each spaxel is saved to a numpy binary file labeled with prefix `q3di['label']` and suffix `_col_row.npy`.

# %%
q3df(q3di, cols=cols, rows=rows, quiet=False)
# Out:
# [col,row]=[20,20] out of [45,41]
# FITLOOP: First call to FITSPEC
# 1.0
# 1.0
# 1.0
# 1.0
# [[Variables]]
#     template_0_amp:        1.82175787 +/- 0.06206876 (3.41%) (init = 7.51)
#     template_1_amp:        0.92774294 +/- 0.08103672 (8.73%) (init = 0.1)
#     blackbody500a:         2.3557e-04 +/- 2.2611e-04 (95.99%) (init = 0.1)
#     blackbody500T:         2997.86163 +/- 8108.32919 (270.47%) (init = 500)
#     blackbody500_ext_Av:   7.26836251 +/- 0.71666882 (9.86%) (init = 0)
#     blackbody500_abs_tau:  7.31558817 +/- 1.95370712 (26.71%) (init = 0)
#     blackbody50a:          7.7191e-10 +/- 4.4442e-08 (5757.40%) (init = 0.1)
#     blackbody50T:          50.0000000 +/- 174.356218 (348.71%) (init = 50)
#     blackbody50_ext_Av:    18.9018978 +/- 54.4486485 (288.06%) (init = 0)
#     blackbody50_abs_tau:   1.3831e-06 +/- 10904.3978 (788382916130.93%) (init = 0)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(blackbody50a, blackbody50_ext_Av)          = -1.000
#     C(blackbody500a, blackbody500_ext_Av)        = -1.000
#     C(blackbody50a, blackbody50T)                = -0.984
#     C(blackbody50T, blackbody50_ext_Av)          = 0.984
#     C(blackbody500_abs_tau, blackbody50_abs_tau) = -0.932
#     C(blackbody500T, blackbody50T)               = 0.658
#     C(blackbody500T, blackbody500_ext_Av)        = -0.646
#     C(template_1_amp, blackbody50_ext_Av)        = 0.644
#     C(template_1_amp, blackbody50a)              = -0.644
#     C(blackbody500a, blackbody500T)              = 0.641
#     C(template_0_amp, blackbody500a)             = -0.609
#     C(template_0_amp, blackbody500_ext_Av)       = 0.606
#     C(template_0_amp, blackbody50a)              = -0.594
#     C(template_0_amp, blackbody50_ext_Av)        = 0.594
#     C(blackbody500T, blackbody50_ext_Av)         = 0.570
#     C(blackbody500T, blackbody50a)               = -0.570
#     C(template_0_amp, blackbody50T)              = 0.548
#     C(template_1_amp, blackbody500a)             = -0.548
#     C(template_1_amp, blackbody500_ext_Av)       = 0.528
#     C(template_1_amp, blackbody50T)              = 0.527
#     C(template_0_amp, template_1_amp)            = 0.449
#     C(blackbody500_abs_tau, blackbody50T)        = 0.201
#     C(blackbody500_abs_tau, blackbody50a)        = -0.195
#     C(blackbody500_abs_tau, blackbody50_ext_Av)  = 0.195
#     C(blackbody500a, blackbody50a)               = 0.177
#     C(blackbody500a, blackbody50_ext_Av)         = -0.177
#     C(blackbody500T, blackbody500_abs_tau)       = 0.165
#     C(blackbody500_ext_Av, blackbody50a)         = -0.161
#     C(blackbody500_ext_Av, blackbody50_ext_Av)   = 0.160
#     C(template_0_amp, blackbody500_abs_tau)      = 0.116
#     C(template_1_amp, blackbody50_abs_tau)       = 0.103
# FITSPEC: Continuum fit took 34.2 s.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.4506e+07                                    1.26e+05
#        1              2         1.4463e+07      4.32e+04       9.12e+02       2.26e+05
#        2              3         1.4324e+07      1.39e+05       1.15e+03       3.07e+05
#        3              4         1.4222e+07      1.02e+05       6.55e+02       1.60e+05
#        4              5         1.4189e+07      3.33e+04       2.40e+02       5.39e+04
#        5              6         1.4188e+07      5.99e+02       2.23e-02       4.88e+03
#        6              7         1.4183e+07      4.81e+03       4.17e+01       9.08e+03
#        7              8         1.4183e+07      1.68e+01       3.71e-03       4.01e+01
#        8             10         1.4183e+07      1.30e+00       1.13e-02       3.88e+01
#        9             11         1.4183e+07      2.56e+00       2.22e-02       3.62e+01
#       10             12         1.4183e+07      4.94e+00       4.29e-02       3.13e+01
#       11             13         1.4183e+07      9.18e+00       7.97e-02       2.21e+01
#       12             14         1.4183e+07      1.50e+01       1.30e-01       2.81e+01
#       13             15         1.4183e+07      7.09e+00       6.16e-02       2.98e+01
#       14             16         1.4183e+07      2.52e-02       2.19e-04       2.91e+01
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.4506e+07, final cost 1.4183e+07, first-order optimality 2.91e+01.
# [[Model]]
#     (((((((Model(manygauss, prefix='H2_00_S5_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>') + Model(manygauss, prefix='lbArIIrb6pt99_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbArIIIrb8pt99_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbNeIIrb12pt81_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbNeIIIrb15pt56_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='H2_00_S3_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='H2_00_S1_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbSIIIrb18pt71_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>'))
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 16
#     # data points      = 2093
#     # variables        = 4
#     chi-square         = 28366642.6
#     reduced chi-square = 13579.0534
#     Akaike info crit   = 19921.5779
#     Bayesian info crit = 19944.1634
# ##  Warning: uncertainties could not be estimated:
#     lbNeIIrb12pt81_0_cwv:   at boundary
#     lbNeIIrb12pt81_0_sig:   at boundary
#     H2_00_S3_0_flx:         at boundary
# [[Variables]]
#     H2_00_S5_0_flx:         0 (fixed)
#     H2_00_S5_0_cwv:         6.88879156 == '6.909520e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     H2_00_S5_0_sig:         4000.00000 == 'lbNeIIrb12pt81_0_sig'
#     lbArIIrb6pt99_0_flx:    0 (fixed)
#     lbArIIrb6pt99_0_cwv:    6.96431828 == '6.985274e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbArIIrb6pt99_0_sig:    4000.00000 == 'lbNeIIrb12pt81_0_sig'
#     lbArIIIrb8pt99_0_flx:   0.54258265 (init = 0.2836888)
#     lbArIIIrb8pt99_0_cwv:   8.96440601 == '8.991380e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbArIIIrb8pt99_0_sig:   4000.00000 == 'lbNeIIrb12pt81_0_sig'
#     lbNeIIrb12pt81_0_flx:   0 (fixed)
#     lbNeIIrb12pt81_0_cwv:   12.7751093 (init = 12.81355)
#     lbNeIIrb12pt81_0_sig:   4000.00000 (init = 1000)
#     lbNeIIIrb15pt56_0_flx:  0 (fixed)
#     lbNeIIIrb15pt56_0_cwv:  15.5084347 == '1.555510e+01 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbNeIIIrb15pt56_0_sig:  4000.00000 == 'lbNeIIrb12pt81_0_sig'
#     H2_00_S3_0_flx:         1.2118e-35 (init = 0)
#     H2_00_S3_0_cwv:         9.63592529 == '9.664920e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     H2_00_S3_0_sig:         4000.00000 == 'lbNeIIrb12pt81_0_sig'
#     H2_00_S1_0_flx:         0 (fixed)
#     H2_00_S1_0_cwv:         16.9837360 == '1.703484e+01 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     H2_00_S1_0_sig:         4000.00000 == 'lbNeIIrb12pt81_0_sig'
#     lbSIIIrb18pt71_0_flx:   0 (fixed)
#     lbSIIIrb18pt71_0_cwv:   18.6568610 == '1.871300e+01 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbSIIIrb18pt71_0_sig:   4000.00000 == 'lbNeIIrb12pt81_0_sig'
# FITSPEC: Line fit took 0.3 s.
# FIT STATUS: 2
# FITLOOP: Second call to FITSPEC
# 1.0
# 1.0
# 1.0
# 1.0
# [[Variables]]
#     template_0_amp:        1.91357614 +/- 0.04734227 (2.47%) (init = 7.51)
#     template_1_amp:        0.96264984 +/- 0.08659086 (9.00%) (init = 0.1)
#     blackbody500a:         1.4012e-06 +/- 2.6839e-06 (191.55%) (init = 0.1)
#     blackbody500T:         2994.34510 +/- 9244.96314 (308.75%) (init = 500)
#     blackbody500_ext_Av:   11.3454030 +/- 1.46546477 (12.92%) (init = 0)
#     blackbody500_abs_tau:  8.74836946 +/- 2.41120630 (27.56%) (init = 0)
#     blackbody50a:          1.1950e-09 +/- 6.7777e-08 (5671.61%) (init = 0.1)
#     blackbody50T:          50.0000000 +/- 168.419473 (336.84%) (init = 50)
#     blackbody50_ext_Av:    18.6134981 +/- 53.6160498 (288.05%) (init = 0)
#     blackbody50_abs_tau:   1.9086e-07 +/- 11817.9363 (6191956345210.37%) (init = 0)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(blackbody50a, blackbody50_ext_Av)          = -1.000
#     C(blackbody500a, blackbody500_ext_Av)        = -1.000
#     C(blackbody50a, blackbody50T)                = -0.988
#     C(blackbody50T, blackbody50_ext_Av)          = 0.988
#     C(blackbody500_abs_tau, blackbody50_abs_tau) = -0.955
#     C(template_1_amp, blackbody500a)             = -0.772
#     C(template_1_amp, blackbody500_ext_Av)       = 0.768
#     C(template_1_amp, blackbody50_ext_Av)        = 0.627
#     C(template_1_amp, blackbody50a)              = -0.627
#     C(blackbody500_ext_Av, blackbody50_ext_Av)   = 0.596
#     C(blackbody500_ext_Av, blackbody50a)         = -0.596
#     C(blackbody500a, blackbody50_ext_Av)         = -0.591
#     C(blackbody500a, blackbody50a)               = 0.591
#     C(blackbody500a, blackbody500T)              = 0.572
#     C(blackbody500T, blackbody500_ext_Av)        = -0.563
#     C(template_1_amp, blackbody50T)              = 0.526
#     C(blackbody500_ext_Av, blackbody50T)         = 0.520
#     C(blackbody500a, blackbody50T)               = -0.513
#     C(template_0_amp, blackbody500_ext_Av)       = 0.422
#     C(template_0_amp, blackbody500a)             = -0.419
#     C(template_0_amp, blackbody50a)              = -0.373
#     C(template_0_amp, blackbody50_ext_Av)        = 0.373
#     C(template_0_amp, blackbody50T)              = 0.360
#     C(blackbody500T, blackbody50T)               = 0.355
#     C(template_1_amp, blackbody500T)             = -0.328
#     C(blackbody500T, blackbody50a)               = -0.268
#     C(blackbody500T, blackbody50_ext_Av)         = 0.268
#     C(blackbody500T, blackbody500_abs_tau)       = 0.122
#     C(blackbody500_abs_tau, blackbody50T)        = 0.117
#     C(blackbody500_abs_tau, blackbody50a)        = -0.111
#     C(blackbody500_abs_tau, blackbody50_ext_Av)  = 0.111
# FITSPEC: Continuum fit took 41.3 s.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.4577e+07                                    7.96e+05
#        1              2         1.4224e+07      3.53e+05       3.34e-01       2.73e+05
#        2              3         1.4190e+07      3.49e+04       1.15e-01       2.23e+04
#        3              4         1.4189e+07      2.02e+02       9.38e-03       2.39e+02
#        4              5         1.4189e+07      4.96e-01       1.01e-04       1.68e+00
#        5              6         1.4189e+07      2.42e-03       7.08e-07       9.71e-03
# Both `ftol` and `xtol` termination conditions are satisfied.
# Function evaluations 6, initial cost 1.4577e+07, final cost 1.4189e+07, first-order optimality 9.71e-03.
# [[Model]]
#     (((((((Model(manygauss, prefix='H2_00_S5_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>') + Model(manygauss, prefix='lbArIIrb6pt99_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbArIIIrb8pt99_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbNeIIrb12pt81_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbNeIIIrb15pt56_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='H2_00_S3_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='H2_00_S1_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>')) + Model(manygauss, prefix='lbSIIIrb18pt71_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff9c14aa820>'))
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 6
#     # data points      = 2093
#     # variables        = 4
#     chi-square         = 28378771.7
#     reduced chi-square = 13584.8596
#     Akaike info crit   = 19922.4727
#     Bayesian info crit = 19945.0581
# [[Variables]]
#     H2_00_S5_0_flx:         0 (fixed)
#     H2_00_S5_0_cwv:         6.86812504 +/- 0.00978968 (0.14%) == '6.909520e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     H2_00_S5_0_sig:         4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
#     lbArIIrb6pt99_0_flx:    0 (fixed)
#     lbArIIrb6pt99_0_cwv:    6.94342520 +/- 0.00989701 (0.14%) == '6.985274e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbArIIrb6pt99_0_sig:    4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
#     lbArIIIrb8pt99_0_flx:   0.99970433 +/- 0.09297506 (9.30%) (init = 0.5425826)
#     lbArIIIrb8pt99_0_cwv:   8.93751261 +/- 0.01273935 (0.14%) == '8.991380e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbArIIIrb8pt99_0_sig:   4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
#     lbNeIIrb12pt81_0_flx:   0 (fixed)
#     lbNeIIrb12pt81_0_cwv:   12.7367840 +/- 0.01815475 (0.14%) (init = 12.77511)
#     lbNeIIrb12pt81_0_sig:   4000.00000 +/- 420.104935 (10.50%) (init = 4000)
#     lbNeIIIrb15pt56_0_flx:  0 (fixed)
#     lbNeIIIrb15pt56_0_cwv:  15.4619093 +/- 0.02203909 (0.14%) == '1.555510e+01 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbNeIIIrb15pt56_0_sig:  4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
#     H2_00_S3_0_flx:         7.1038e-22 +/- 0.05978973 (8416637112766914625536.00%) (init = 1.211805e-35)
#     H2_00_S3_0_cwv:         9.60701752 +/- 0.01369364 (0.14%) == '9.664920e+00 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     H2_00_S3_0_sig:         4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
#     H2_00_S1_0_flx:         0 (fixed)
#     H2_00_S1_0_cwv:         16.9327850 +/- 0.02413564 (0.14%) == '1.703484e+01 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     H2_00_S1_0_sig:         4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
#     lbSIIIrb18pt71_0_flx:   0 (fixed)
#     lbSIIIrb18pt71_0_cwv:   18.6008911 +/- 0.02651332 (0.14%) == '1.871300e+01 / 1.281355e+01 * lbNeIIrb12pt81_0_cwv'
#     lbSIIIrb18pt71_0_sig:   4000.00000 +/- 420.104935 (10.50%) == 'lbNeIIrb12pt81_0_sig'
# FITSPEC: Line fit took 0.1 s.
# FIT STATUS: 2

# %% [markdown]
# Plot the results. The resulting plots are saved as `.jpg` files. Data from multiple spaxels are collated into dictionaries containing emission-line and continuum best-fit parameters and saved to various ancillary files.

# %%
q3da(q3di, cols=cols, rows=rows)
