# %% [markdown]
# # q3dfit notebook: NIRSPEC, J1652, no PSF subtraction

# %% [markdown]
# <h3><font color='teal'>Installation of the environment and the package are described <a href="https://q3dfit.readthedocs.io/">here</a>. </font></h3>

# %% [markdown]
# This Jupyter notebook allows you to run Q3Dfit, a PSF decomposition and spectral analysis package tailored for JWST NIRSpec and MIRI IFU observations.
#
# Q3Dfit is developed as a science-enabling data product by the Early Release Science Team #1335 Q3D. You can find more information about this ERS program **Q3D** [here](https://wwwstaff.ari.uni-heidelberg.de/dwylezalek/q3d.html) and [here](https://www.stsci.edu/jwst/science-execution/approved-programs/dd-ers/program-1335).
#
# The software is based on the existing package IFSFIT developed by Dave Rupke (see [ADS link](https://ui.adsabs.harvard.edu/abs/2017ApJ...850...40R/abstract)).
#
# The following notebook will guide you through the initialization procedure and will then perform the analysis.

# %% [markdown]
# ## Table of Contents
#
# * [1. Initialization](#chapter1)
#     * [1.0. Setting up the directory tree](#chapter1_0)
#     * [1.1. Setting up the data and models](#chapter1_1)
#     * [1.2. Setting up the fitting parameters](#chapter1_2)
#         * [1.2.1. Emission line parameters](#chapter1_2_1)
#         * [1.2.2. Continuum parameters](#chapter1_2_2)
#     * [1.3. Setting up the plotting parameters](#chapter1_3)
# * [2. Run fitting and plotting routines](#chapter2)

# %% [markdown]
# ## 1. Initialization <a class="anchor" id="chapter1"></a>

# %%
import os.path
import numpy as np
# %matplotlib inline
# unless you are running this python notebook from the directory where q3dfit is installed, you need to point the
# path to the package in order to import it. 
import sys
sys.path.append("")
sys.path.append("../")

# %%
# Convenience function
# Ref: https://github.com/spacetelescope/jwebbinar_prep/blob/main/imaging_mode/imaging_mode_stage_1.ipynb
from astropy.utils.data import download_file
def download_files(files, output_directory, force=False):
    """Given a tuple or list of tuples containing (URL, filename),
    download the given files into the current working directory.
    Downloading is done via astropy's download_file. A symbolic link
    is created in the specified output dirctory that points to the
    downloaded file.
    
    Parameters
    ----------
    files : tuple or list of tuples
        Each 2-tuple should contain (URL, filename), where
        URL is the URL from which to download the file, and
        filename will be the name of the symlink pointing to
        the downloaded file.
        
    output_directory : str
        Name of the directory in which to create the symbolic
        links to the downloaded files
        
    force : bool
        If True, the file will be downloaded regarless of whether
        it is already present or not.
                
    Returns
    -------
    filenames : list
        List of filenames corresponding to the symbolic links
        of the downloaded files
    """
    # In the case of a single input tuple, make it a
    # 1 element list, for consistency.
    filenames = []
    if isinstance(files, tuple):
        files = [files]
        
    for file in files:
        filenames.append(file[1])
        if force:
            print('Downloading {}...'.format(file[1]))
            demo_file = download_file(file[0], cache='update')
            # Make a symbolic link using a local name for convenience
            if not os.path.islink(os.path.join(output_directory, file[1])):
                os.symlink(demo_file, os.path.join(output_directory, file[1]))
        else:
            if not os.path.isfile(os.path.join(output_directory, file[1])):
                print('Downloading {}...'.format(file[1]))
                demo_file = download_file(file[0], cache=True)
                # Make a symbolic link using a local name for convenience
                os.symlink(demo_file, os.path.join(output_directory, file[1]))
            else:
                print('{} already exists, skipping download...'.format(file[1]))
                continue
    return filenames

# %% [markdown]
# ### 1.0. Setting up the directory tree <a class="anchor" id="chapter1_0"></a>
#
# Define the directories in which the data cube(s) that you want to analyse are stored and the output directories. We recommend creating a working directory that you name after your target, in which all outputs from q3dfit will be saved. Then download test data.

# %%
# Base directory (book-keeping)
volume = 'nirspec-j1652/'
# prefix label for output files
gal = 'nirspec-j1652'
# Input directory
indir = volume
if not os.path.exists(indir):
    os.makedirs(indir)
# Output directory
outdir = volume
if not os.path.exists(outdir):
    os.makedirs(outdir)
# Initialization file (q3di.npy) directory
initdir = volume
# Output logfile
logfile = outdir+gal+'-fitlog.txt'

# %% [markdown]
# Download data from public Box folder:

# %%
# make tuples of urls and download filenames
# infile = data cube
infile_tup=('https://rhodes.box.com/shared/static/3tv287h685rertaia6uszxt3cs01e2jo.fits','nirspec-j1652.fits')
# download files; by default don't force overwrite and take first element of output
infile = download_files(infile_tup, outdir, force=False)[0]
# add subdirectory to filenames
infile = outdir+infile
# Out:
# nirspec-j1652.fits already exists, skipping download...

# %% [markdown]
# ### 1.1. Setting up the data and models <a class="anchor" id="chapter1_1"></a>
#
# Some general information about your cube. `argsreadcube` is a dictionary of attributes sent to the `CUBE` class.
# - For non-JWST data, set `wmapext` to `None`. The WMAP extension is a [3-D weight image](https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/science_products.html) giving the relative weights of the output spaxels.
# - Microns are the wavelength unit used internally, but `q3dfit` can accept other wavelength input units or output other units.
# - The code does calculations in flambda space, but assumes input units of MJy/sr, the JWST default. Other input wavelength units can be specified.

# %%
from q3dfit.readcube import Cube
argscube = {'wmapext': None, 'pixarea_sqas': 0.0025, 'fluxnorm': 1e-8}
if not os.path.isfile(infile): 
    print('Data cube not found.')
else:
    cube = Cube(infile, datext=0, varext=1, dqext=2, **argscube)
    ncols = cube.ncols # number of columns
    nrows = cube.nrows # number of rows
    cube.about()
# Out:
# Cube: Negative values encountered in variance array. Taking absolute value.
# Size of data cube: [ 89 , 81 , 1843 ]
# Wavelength range: [ 1.700016528205231 , 2.429448507097766 ]  micron

# %% [markdown]
# Name and systemic redshift of the galaxy. `zsys` is presently not used within the code, but would be an input for, e.g., calculating velocity maps in routines under development (e.g., `makemaps.py`). It is used in this notebook in initializing the arrays of initial guesses below.

# %%
name = 'J1652'
zsys_gas = 2.948

# %% [markdown]
# Wavelength range over which to fit data and the range of wavelength to ignore:

# %%
fitrange = [1.75,2.3] #in um
#cutrange = np.array([2.41,2.47])

# %% [markdown]
# Generating the quasar template used for PSF subtraction:

# %%
from q3dfit.makeqsotemplate import makeqsotemplate
qsotemplate = volume+'nirspec-j1652-quasar-template.npy'
makeqsotemplate(infile, qsotemplate, radius=2.5, 
                argscube={'wmapext':None, 'datext':0, 'varext':1, 'dqext':2, 'pixarea_sqas':0.0025, 'fluxnorm':5e-5})
# Out:
# Cube: Negative values encountered in variance array. Taking absolute value.

# %% [markdown]
# ### 1.2. Setting up the fitting parameters <a class="anchor" id="chapter1_2"></a>

# %% [markdown]
# #### 1.2.1. Emission-line parameters <a class="anchor" id="chapter1_2_1"></a>

# %% [markdown]
# What lines do you want to fit? You can choose from the linelists available [here](https://github.com/Q3D/q3dfit/tree/main/data/linelists), or in `q3dfit/data/linelists/`.

# %%
lines = ['HeII4686', 'Hbeta', '[OIII]4959', '[OIII]5007']

# %% [markdown]
# How many components do you want to be fitted to the emission lines?

# %%
maxncomp = 1

# %% [markdown]
# This block sets up initial conditions for the emission-line fit to each spaxel. Emission lines are set to a common redshift and velocity dispersion. However, different sets of emission lines can have different velocities and linewidths by specifying different lines to which to tie particular emission lines.

# %%
linetie = dict()
ncomp = dict()
zinit_gas = dict()
siginit_gas = dict()
for i in lines:
    linetie[i] = 'Hbeta'
    ncomp[i] = np.full((ncols,nrows),maxncomp)
    zinit_gas[i] = np.full((ncols,nrows,maxncomp),zsys_gas)
    siginit_gas[i] = np.full((ncols,nrows,maxncomp),200.)

# %% [markdown]
# `siglim_gas` sets lower and upper bounds for the Gaussian width (sigma) of the emission line. These limits can be set globablly, for all spaxels and components, by defining a 2-element array. The limits can also be set for individual spaxels (but all components) by defining an (Ncol x Nrow x 2) array.

# %%
# Global limit
siglim_gas = np.array([5., 2000.])

# Spaxel-by-spaxel limit
# siglim_gas = np.ndarray((dx, dy, 2))
# siglim_gas[:,:,] = array([5.,1000.])
# siglim_gas[13, 10, :] = array([5.,500.])

# %% [markdown]
# #### Spectral resolution convolution
# ##### Just running convolution ---
#
# If no convolution is desired, then set `spectres_convolve` to None.
# If convolution is desired, then `spectres_convolve` and `spect_instrum` are required variables.
#
# Specify the desired convolution method using `spect_instrum`. The syntax is:
# `spect_instrum = {INSTRUMENT:[METHOD]}`, which should mirror the filename in `q3dfit/data/dispersion_files/`. METHOD specifies the grating, spectral resolution [R], Δλ FWHM in [Å], velocity in [km/s].
#
# Examples convolving with:
# 1. flat R=500: `spect_instrum = {'flat':['R500']}`
# 2. flat velocity FWHM = 30km/s: `spect_instrum = {'flat':['kms30']}`
# 3. flat Δλ FWHM = 4 Å: `spect_instrum = {'flat':['dlambda4']}`
# 4. JWST NIRSPEC / G140M: `spect_instrum = {'JWST_NIRSPEC':['G140M']}`
#
# If desired flat convolution file does not exist, then a new file will be created automatically.

# %%
spect_instrum = {'JWST_NIRSPEC':['G235H']}
spectres_convolve = {'ws_instrum':spect_instrum}
#spectres_convolve = None

# %% [markdown]
# ##### Creating convolution files (optional) ---
#
# If the user wants to create a dispersion file, there are 2 methods:
#
# 1. First, run `from q3dfit.common.spectConvol import dispFile` and initialize: `dispObj = dispFile()`
# 2. Create the files with either method A or B
#
# 2.(A) Create a flat R=120 dispersion file from 10 μm to 30 μm:
#
# `dispObj.make_dispersion(120,WAVELEN=[10,30],TYPE='R')`
#
# 2.(B) Create a custom dispersion file with user supplied wavelength and Resolving power lists:
#
# `dispObj.make_custom_dispersion([wavelen list],R=[some R list],FILENAME='custom_RlistA_disp')`
#
# 3. Specify desired dispersion file in convolution: running custom example 2B
#
# `spect_instrum = {'custom':['RlistA']}`

# %%
#from q3dfit.common.spectConvol import dispFile
#dobj = dispFile()
#dispObj.make_custom_dispersion([wavelen list],R=[some R list],FILENAME='custom_RlistA_disp')
#spect_instrum = {'custom':['RlistA']}

# %% [markdown]
# #### 1.2.2 Continuum parameters <a class="anchor" id="chapter1_2_2"></a>

# %% [markdown]
# `q3dfit` first masks emission lines before fitting. This sets is the default mask value in km/s for each velocity component for the first fit. During the second fit, the mask value is set automatically using the best-fit linewidths determined from the first fit.

# %%
maskwidths_def = 1000.

# %% [markdown]
# The continuum fitting parameters specified here are for the case of simultaneous fitting of a stellar and quasar template.
# - `hostord` = [Optional] additive Legendre polynomial for host [starlight] component. Adds components up to order `hostord`.
# - `qsoord` = [Optional] additive Legendre polynomial for host [starlight] component. Adds components up to order `qsoord`.
# - `qsoxdr` = Filename and path of quasar template created earlier with `makeqsotemplate.py`.

# %%
fcncontfit = 'fitqsohost'
argscontfit = dict()
argscontfit['qsoxdr'] = qsotemplate
argscontfit['qsoord'] = 3
argscontfit['hostord'] = 3

# %% [markdown]
# ### 1.3. Setting up the plotting parameters <a class="anchor" id="chapter1_3"></a>

# %% [markdown]
# One dictionary must be defined for a line plot to appear. `argspltlin1` holds the options for the first line plot, and `argspltlin2` is for the second. Parameter options are fed in as keyword/data pairs.
#
# Required keywords in each dictionary:
# * `nx`: Number of subplots in the horizontal direction
# * `ny`: Number of subplots in the vertical direction
# * Options for centerting the plot:
#     - `line`: a string list of line labels
#     - `center_obs`: a float list of wavelengths of each subplot center, in the observed (plotted) frame
#     - `center_rest`: a float list of wavelengths of each subplot center, in the rest frame, which are converted to obs. frame
#
# Optional keywords:
# * `size`: float list of widths in wavelength space of each subplot; if not specified, default is 300 $Å$
# * `IR`: set to `True` to use infrared-style plot

# %%
argspltlin1 = {'nx': 2,
               'ny': 2,
               'line': ['HeII4686', 'Hbeta', '[OIII]4959'],
               'size': [0.05, 0.05,0.07]
              }

# %% [markdown]
# The continuum plot can be changed by specifying several parameters. In this case, we have chosen to output a linear/linear plot of f$_\lambda$ vs. wavelength, in $\mu$m.

# %%
argscontplot = {'xstyle': 'lin',
                'ystyle': 'lin',
                'fluxunit_out': 'flambda',
                'mode': 'dark'}

# %% [markdown]
# The following cell will create the initialisation structure. **Do not change anything in this cell.**

# %%
q3di = {# Required pars
        'fcninitpar': 'parinit',
        'fitran': fitrange,
        'fluxunits': 1,
        'infile': infile,
        'label': gal,
        'lines': lines,
        'linetie': linetie,
        'maxncomp': maxncomp,
        'name': gal,
        'ncomp': ncomp,
        'outdir': outdir,
        'zinit_gas': zinit_gas,
        'zsys_gas': zsys_gas,
        # Optional pars
        'datext':0,'varext':1,'dqext':2,
        'argscontfit': argscontfit,
        'argscontplot': argscontplot,
        'argsreadcube': argscube,
        'argspltlin1': argspltlin1,
        #'cutrange': cutrange,
        'decompose_qso_fit': True,
        'fcncontfit': fcncontfit,
        'logfile': logfile,
        'maskwidths_def': maskwidths_def,
        'siglim_gas': siglim_gas,
        'siginit_gas': siginit_gas,
        'spect_convol':spectres_convolve
        }

# %% [markdown]
# If you want to run `q3dfit` in batch mode, run this cell, which saves q3di to an `npy` file. In your python command line, read in file and run `q3dfit` with
# <pre><code>q3di = '/path/to/the/npy/file/q3di.npy'
# from q3dfit.q3df import q3df
# q3df(q3di,cols=cols,rows=rows)</code></pre>

# %%
q3di_npy = 'q3di.npy'
np.save(initdir+q3di_npy,q3di)

# %% [markdown]
# ## 2. Run fitting and plotting routines <a class="anchor" id="chapter2"></a>

# %%
from q3dfit.q3df import q3df
from q3dfit.q3da import q3da
import q3dfit.q3dpro as q3dpro

# %% [markdown]
# Choose columns and rows to fit. Ranges are specified as two-element lists specifying the first and last spaxel.

# %%
cols = 51
rows = 43
#cc = np.arange(30,60)
#rr = np.arange(72,75)

# %% [markdown]
# Run the fit. Choose `quiet=False` for verbose output. An output dictionary for each spaxel is saved to a numpy binary file labeled with prefix `q3di['label']` and suffix `_col_row.npy`.

# %%
q3df(q3di,cols=cols,rows=rows, quiet=False)
#q3df(q3di, quiet=False)
#for cols in cc:
#    for rows in rr:
#        break
#        q3df(q3di,cols=cols,rows=rows, quiet=True)
# Out:
# [col,row]=[51,43] out of [89,81]
# FITLOOP: First call to FITSPEC
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3908e+12                                    2.97e+11
#        1              2         1.3907e+12      1.86e+07       2.83e-05       2.97e+11
#        2              3         1.3907e+12      3.72e+07       5.66e-05       2.97e+11
#        3              4         1.3906e+12      7.44e+07       1.13e-04       2.97e+11
#        4              5         1.3905e+12      1.49e+08       2.26e-04       2.97e+11
#        5              6         1.3902e+12      2.97e+08       4.53e-04       2.96e+11
#        6              7         1.3896e+12      5.95e+08       9.05e-04       2.96e+11
#        7              8         1.3884e+12      1.19e+09       1.81e-03       2.96e+11
#        8              9         1.3860e+12      2.38e+09       3.62e-03       2.96e+11
#        9             10         1.3813e+12      4.75e+09       7.24e-03       2.95e+11
#       10             11         1.3718e+12      9.47e+09       1.45e-02       2.94e+11
#       11             12         1.3530e+12      1.88e+10       2.90e-02       2.92e+11
#       12             13         1.3157e+12      3.72e+10       5.79e-02       2.88e+11
#       13             14         1.2429e+12      7.28e+10       1.16e-01       2.79e+11
#       14             15         1.1039e+12      1.39e+11       2.32e-01       2.61e+11
#       15             16         8.5238e+11      2.52e+11       4.63e-01       2.26e+11
#       16             17         4.5531e+11      3.97e+11       9.27e-01       1.56e+11
#       17             18         8.4052e+10      3.71e+11       1.85e+00       2.37e+10
#       18             19         4.5572e+10      3.85e+10       3.70e+00       9.70e+09
#       19             20         4.4965e+10      6.07e+08       2.90e-01       2.89e+09
#       20             21         4.2884e+10      2.08e+09       3.78e+00       6.45e+09
#       21             22         4.2165e+10      7.19e+08       9.79e-02       3.93e+09
#       22             23         4.1987e+10      1.78e+08       2.47e-01       1.43e+09
#       23             24         4.1623e+10      3.64e+08       1.30e-01       1.68e+09
#       24             25         4.1454e+10      1.69e+08       3.61e-01       9.39e+08
#       25             26         4.0949e+10      5.05e+08       1.71e-01       1.17e+10
#       26             27         4.0774e+10      1.74e+08       1.18e+00       1.08e+10
#       27             28         4.0661e+10      1.14e+08       3.89e-02       3.91e+08
#       28             29         3.9632e+10      1.03e+09       7.38e+00       3.39e+09
#       29             30         3.9595e+10      3.63e+07       1.85e+00       1.02e+08
#       30             31         3.9566e+10      2.89e+07       3.38e-02       4.22e+09
#       31             32         3.9553e+10      1.32e+07       1.40e-02       9.10e+07
#       32             33         3.9467e+10      8.65e+07       1.14e+01       4.25e+08
#       33             34         3.9462e+10      5.18e+06       1.32e-02       4.03e+08
#       34             35         3.9461e+10      1.02e+06       2.41e-01       8.14e+07
#       35             36         3.9458e+10      2.16e+06       9.45e-03       1.15e+09
#       36             37         3.9457e+10      1.21e+06       4.03e-03       1.65e+07
#       37             38         3.9442e+10      1.51e+07       1.51e-02       1.58e+09
#       38             39         3.9440e+10      1.73e+06       5.20e-03       7.20e+07
#       39             40         3.9433e+10      7.53e+06       6.12e+00       1.69e+08
#       40             41         3.9432e+10      9.29e+05       1.64e-01       8.87e+07
#       41             42         3.9432e+10      1.00e+05       9.20e-04       5.66e+07
#       42             43         3.9431e+10      3.95e+05       3.63e-03       3.99e+08
#       43             44         3.9431e+10      3.25e+05       3.09e-01       2.03e+08
#       44             45         3.9430e+10      1.37e+06       1.99e+00       9.40e+07
#       45             46         3.9429e+10      2.75e+05       4.05e-01       7.48e+07
#       46             47         3.9429e+10      3.37e+05       3.42e-03       2.44e+08
#       47             48         3.9429e+10      4.96e+05       8.89e-01       4.55e+07
#       48             49         3.9428e+10      3.31e+05       3.44e-03       3.94e+08
#       49             50         3.9426e+10      2.18e+06       4.63e+00       1.01e+08
#       50             51         3.9426e+10      4.00e+05       3.69e-03       1.53e+08
#       51             52         3.9426e+10      8.41e+04       3.27e-01       4.55e+07
#       52             53         3.9425e+10      2.39e+05       1.21e-02       1.78e+07
#       53             54         3.9421e+10      4.85e+06       1.38e+01       6.88e+08
#       54             55         3.9420e+10      4.05e+05       1.24e+00       6.33e+07
#       55             56         3.9419e+10      1.12e+06       1.47e+01       1.42e+07
#       56             57         3.9418e+10      5.00e+05       2.91e+01       2.02e+08
#       57             59         3.9418e+10      2.45e+04       6.75e-04       2.00e+07
#       58             60         3.9418e+10      7.78e+04       1.92e+00       2.15e+06
#       59             61         3.9418e+10      9.65e+04       3.79e+00       1.70e+06
#       60             62         3.9418e+10      1.99e+02       9.49e-03       1.71e+06
# `ftol` termination condition is satisfied.
# Function evaluations 62, initial cost 1.3908e+12, final cost 3.9418e+10, first-order optimality 1.71e+06.
# [[Variables]]
#     stars_add_exp_a:  74.5306312 (init = 0)
#     stars_add_exp_b:  0.14225317 (init = 0)
#     stars_add_exp_c:  15.9196240 (init = 0)
#     stars_add_exp_d:  1.0255e-12 (init = 0)
#     stars_add_exp_e:  5.2543e-07 (init = 0)
#     stars_add_exp_f:  5.2635e-07 (init = 0)
#     stars_add_exp_g:  1.2102e-06 (init = 0)
#     stars_add_exp_h:  1.2102e-06 (init = 0)
#     stars_add_leg_i:  3.5569e-13 (init = 0)
#     stars_add_leg_j:  3.6143e-12 (init = 0)
#     stars_add_leg_k:  5.8334e-26 (init = 0)
#     stars_add_leg_l:  2.0664e-12 (init = 0)
#     stars_add_leg_m:  0 (fixed)
#     stars_add_leg_n:  0 (fixed)
#     stars_add_leg_o:  0 (fixed)
#     stars_add_leg_p:  0 (fixed)
#     stars_add_leg_q:  0 (fixed)
#     stars_add_leg_r:  0 (fixed)
#     qso_mult_exp_a:   0.01023888 (init = 0)
#     qso_mult_exp_b:   0.00112969 (init = 0)
#     qso_mult_exp_c:   7.3287e-06 (init = 0)
#     qso_mult_exp_d:   5.62913253 (init = 0)
#     qso_mult_exp_e:   1.0005e-10 (init = 0)
#     qso_mult_exp_f:   1.0084e-10 (init = 0)
#     qso_mult_exp_g:   9.9804e-11 (init = 0)
#     qso_mult_exp_h:   9.9016e-11 (init = 0)
#     qso_mult_leg_i:   5.84204364 (init = 0)
#     qso_mult_leg_j:   0.70935534 (init = 0)
#     qso_mult_leg_k:   1.7961e-24 (init = 0)
#     qso_mult_leg_l:   4.1664e-11 (init = 0)
#     qso_mult_leg_m:   0 (fixed)
#     qso_mult_leg_n:   0 (fixed)
#     qso_mult_leg_o:   0 (fixed)
#     qso_mult_leg_p:   0 (fixed)
#     qso_mult_leg_q:   0 (fixed)
#     qso_mult_leg_r:   0 (fixed)
# FITSPEC: Continuum fit took 1.2 s.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.8493e+11                                    1.38e+12
#        1              2         1.0596e+11      7.90e+10       7.15e+01       1.50e+11
#        2              3         1.0068e+11      5.29e+09       2.30e+01       3.27e+10
#        3              4         9.8277e+10      2.40e+09       2.78e+01       2.05e+10
#        4              5         9.7255e+10      1.02e+09       1.92e+01       1.39e+10
#        5              6         9.6849e+10      4.05e+08       1.21e+01       9.05e+09
#        6              7         9.6693e+10      1.56e+08       7.49e+00       5.73e+09
#        7              8         9.6634e+10      5.92e+07       4.59e+00       3.56e+09
#        8              9         9.6612e+10      2.21e+07       2.79e+00       2.18e+09
#        9             10         9.6604e+10      8.14e+06       1.69e+00       1.33e+09
#       10             11         9.6601e+10      2.98e+06       1.02e+00       8.05e+08
#       11             12         9.6600e+10      1.09e+06       6.17e-01       4.87e+08
#       12             13         9.6599e+10      3.96e+05       3.72e-01       2.94e+08
#       13             14         9.6599e+10      1.44e+05       2.24e-01       1.77e+08
#       14             15         9.6599e+10      5.22e+04       1.35e-01       1.07e+08
#       15             16         9.6599e+10      1.89e+04       8.13e-02       6.43e+07
#       16             17         9.6599e+10      6.86e+03       4.90e-02       3.87e+07
#       17             18         9.6599e+10      2.49e+03       2.95e-02       2.33e+07
#       18             19         9.6599e+10      9.01e+02       1.77e-02       1.40e+07
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 1.8493e+11, final cost 9.6599e+10, first-order optimality 1.40e+07.
# [[Model]]
#     (((Model(manygauss, prefix='HeII4686_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>') + Model(manygauss, prefix='Hbeta_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>')) + Model(manygauss, prefix='lbOIIIrb4959_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>')) + Model(manygauss, prefix='lbOIIIrb5007_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>'))
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 19
#     # data points      = 1389
#     # variables        = 5
#     chi-square         = 1.9320e+11
#     reduced chi-square = 1.3959e+08
#     Akaike info crit   = 26054.6414
#     Bayesian info crit = 26080.8230
# [[Variables]]
#     HeII4686_0_flx:      7.80320187 +/- 1.61989806 (20.76%) (init = 7.001067)
#     HeII4686_0_cwv:      1.85146427 +/- 1.6945e-05 (0.00%) == '4.688012e-01 / 4.862708e-01 * Hbeta_0_cwv'
#     HeII4686_0_sig:      166.612374 +/- 2.70507317 (1.62%) == 'Hbeta_0_sig'
#     Hbeta_0_flx:         33.2617916 +/- 2.55656880 (7.69%) (init = 28.70563)
#     Hbeta_0_cwv:         1.92045799 +/- 1.7576e-05 (0.00%) (init = 1.919797)
#     Hbeta_0_sig:         166.612374 +/- 2.70507317 (1.62%) (init = 200)
#     lbOIIIrb4959_0_flx:  135.163942 +/- 2.71725307 (2.01%) == 'lbOIIIrb5007_0_flx/3.'
#     lbOIIIrb4959_0_cwv:  1.95899821 +/- 1.7929e-05 (0.00%) == '4.960294e-01 / 4.862708e-01 * Hbeta_0_cwv'
#     lbOIIIrb4959_0_sig:  166.612374 +/- 2.70507317 (1.62%) == 'Hbeta_0_sig'
#     lbOIIIrb5007_0_flx:  405.491826 +/- 8.15175919 (2.01%) (init = 389.5095)
#     lbOIIIrb5007_0_cwv:  1.97793262 +/- 1.8102e-05 (0.00%) == '5.008237e-01 / 4.862708e-01 * Hbeta_0_cwv'
#     lbOIIIrb5007_0_sig:  166.612374 +/- 2.70507317 (1.62%) == 'Hbeta_0_sig'
# FITSPEC: Line fit took 0.6 s.
# FIT STATUS: 2
# FITLOOP: Second call to FITSPEC
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.7140e+12                                    3.15e+11
#        1              2         1.7139e+12      1.90e+07       2.65e-05       3.15e+11
#        2              3         1.7139e+12      3.81e+07       5.29e-05       3.15e+11
#        3              4         1.7138e+12      7.62e+07       1.06e-04       3.15e+11
#        4              5         1.7137e+12      1.52e+08       2.12e-04       3.15e+11
#        5              6         1.7134e+12      3.05e+08       4.23e-04       3.15e+11
#        6              7         1.7128e+12      6.09e+08       8.47e-04       3.15e+11
#        7              8         1.7115e+12      1.22e+09       1.69e-03       3.15e+11
#        8              9         1.7091e+12      2.44e+09       3.39e-03       3.14e+11
#        9             10         1.7042e+12      4.86e+09       6.77e-03       3.14e+11
#       10             11         1.6945e+12      9.71e+09       1.35e-02       3.13e+11
#       11             12         1.6752e+12      1.93e+10       2.71e-02       3.11e+11
#       12             13         1.6370e+12      3.83e+10       5.42e-02       3.06e+11
#       13             14         1.5620e+12      7.50e+10       1.08e-01       2.98e+11
#       14             15         1.4180e+12      1.44e+11       2.17e-01       2.81e+11
#       15             16         1.1544e+12      2.64e+11       4.33e-01       2.47e+11
#       16             17         7.2358e+11      4.31e+11       8.67e-01       1.80e+11
#       17             18         2.4441e+11      4.79e+11       1.73e+00       6.06e+10
#       18             19         1.1574e+11      1.29e+11       3.47e+00       7.87e+09
#       19             20         1.1202e+11      3.72e+09       4.95e-01       1.71e+10
#       20             21         1.1064e+11      1.39e+09       1.09e-01       3.65e+09
#       21             23         1.0149e+11      9.15e+09       1.61e+00       2.37e+10
#       22             24         1.0060e+11      8.91e+08       1.01e-01       1.10e+09
#       23             25         9.9257e+10      1.34e+09       2.16e+00       1.11e+10
#       24             26         9.8784e+10      4.73e+08       1.15e+00       3.69e+09
#       25             27         9.7864e+10      9.20e+08       3.32e+00       1.62e+09
#       26             28         9.7835e+10      2.99e+07       1.80e-01       1.45e+08
#       27             29         9.7785e+10      4.99e+07       2.91e+00       5.80e+09
#       28             30         9.7699e+10      8.55e+07       4.57e+00       3.65e+08
#       29             31         9.7652e+10      4.75e+07       6.77e+00       1.71e+08
#       30             32         9.7650e+10      1.76e+06       1.85e+00       4.21e+07
#       31             33         9.7646e+10      3.45e+06       4.77e+00       3.61e+07
#       32             34         9.7646e+10      8.72e+04       1.61e-03       1.77e+08
#       33             35         9.7646e+10      1.77e+05       3.31e-01       1.73e+08
#       34             36         9.7646e+10      2.64e+04       5.21e-04       7.43e+06
#       35             37         9.7646e+10      3.86e+05       7.53e-01       1.18e+08
#       36             38         9.7646e+10      8.44e+04       1.70e-01       1.16e+08
#       37             39         9.7645e+10      3.27e+05       1.07e+00       8.19e+07
#       38             40         9.7645e+10      1.81e+05       2.34e-03       5.77e+07
#       39             42         9.7639e+10      5.93e+06       9.28e-01       3.19e+07
#       40             43         9.7639e+10      4.93e+05       9.06e-01       1.24e+07
#       41             44         9.7639e+10      2.99e+03       3.06e-04       1.47e+06
#       42             45         9.7639e+10      1.31e+03       9.35e-03       2.07e+06
#       43             46         9.7639e+10      2.04e+02       3.39e-02       3.53e+06
# `ftol` termination condition is satisfied.
# Function evaluations 46, initial cost 1.7140e+12, final cost 9.7639e+10, first-order optimality 3.53e+06.
# [[Variables]]
#     stars_add_exp_a:  21.7253992 (init = 0)
#     stars_add_exp_b:  1.3545e-06 (init = 0)
#     stars_add_exp_c:  21.7566677 (init = 0)
#     stars_add_exp_d:  1.0154e-06 (init = 0)
#     stars_add_exp_e:  1.0586e-12 (init = 0)
#     stars_add_exp_f:  1.1576e-04 (init = 0)
#     stars_add_exp_g:  1.5041e-06 (init = 0)
#     stars_add_exp_h:  1.5041e-06 (init = 0)
#     stars_add_leg_i:  1.5027e-09 (init = 0)
#     stars_add_leg_j:  1.2739e-05 (init = 0)
#     stars_add_leg_k:  3.4452e-12 (init = 0)
#     stars_add_leg_l:  1.2165e-08 (init = 0)
#     stars_add_leg_m:  0 (fixed)
#     stars_add_leg_n:  0 (fixed)
#     stars_add_leg_o:  0 (fixed)
#     stars_add_leg_p:  0 (fixed)
#     stars_add_leg_q:  0 (fixed)
#     stars_add_leg_r:  0 (fixed)
#     qso_mult_exp_a:   1.4109e-05 (init = 0)
#     qso_mult_exp_b:   6.72796585 (init = 0)
#     qso_mult_exp_c:   0.09054026 (init = 0)
#     qso_mult_exp_d:   1.2090e-04 (init = 0)
#     qso_mult_exp_e:   1.0003e-10 (init = 0)
#     qso_mult_exp_f:   1.0026e-10 (init = 0)
#     qso_mult_exp_g:   9.9700e-11 (init = 0)
#     qso_mult_exp_h:   1.0007e-10 (init = 0)
#     qso_mult_leg_i:   5.19922684 (init = 0)
#     qso_mult_leg_j:   0.43442915 (init = 0)
#     qso_mult_leg_k:   3.8976e-18 (init = 0)
#     qso_mult_leg_l:   0.71694970 (init = 0)
#     qso_mult_leg_m:   0 (fixed)
#     qso_mult_leg_n:   0 (fixed)
#     qso_mult_leg_o:   0 (fixed)
#     qso_mult_leg_p:   0 (fixed)
#     qso_mult_leg_q:   0 (fixed)
#     qso_mult_leg_r:   0 (fixed)
# FITSPEC: Continuum fit took 0.8 s.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.5052e+10                                    1.84e+10
#        1              2         9.4756e+10      2.96e+08       3.51e+00       4.96e+09
#        2              3         9.4714e+10      4.25e+07       3.87e+00       2.81e+09
#        3              4         9.4700e+10      1.42e+07       2.32e+00       1.64e+09
#        4              5         9.4695e+10      4.77e+06       1.35e+00       9.56e+08
#        5              6         9.4693e+10      1.60e+06       7.78e-01       5.54e+08
#        6              7         9.4693e+10      5.33e+05       4.49e-01       3.20e+08
#        7              8         9.4693e+10      1.78e+05       2.59e-01       1.85e+08
#        8              9         9.4692e+10      5.90e+04       1.49e-01       1.07e+08
#        9             10         9.4692e+10      1.96e+04       8.60e-02       6.15e+07
#       10             11         9.4692e+10      6.52e+03       4.96e-02       3.55e+07
#       11             12         9.4692e+10      2.16e+03       2.86e-02       2.04e+07
#       12             13         9.4692e+10      7.19e+02       1.65e-02       1.18e+07
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.5052e+10, final cost 9.4692e+10, first-order optimality 1.18e+07.
# [[Model]]
#     (((Model(manygauss, prefix='HeII4686_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>') + Model(manygauss, prefix='Hbeta_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>')) + Model(manygauss, prefix='lbOIIIrb4959_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>')) + Model(manygauss, prefix='lbOIIIrb5007_0_', SPECRES='<q3dfit.spectConvol.spectConvol object at 0x7ff641bf87c0>'))
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 13
#     # data points      = 1389
#     # variables        = 5
#     chi-square         = 1.8938e+11
#     reduced chi-square = 1.3684e+08
#     Akaike info crit   = 26026.9536
#     Bayesian info crit = 26053.1353
# [[Variables]]
#     HeII4686_0_flx:      6.70536396 +/- 1.64270993 (24.50%) (init = 7.803202)
#     HeII4686_0_cwv:      1.85147135 +/- 1.6543e-05 (0.00%) == '4.688012e-01 / 4.862708e-01 * Hbeta_0_cwv'
#     HeII4686_0_sig:      160.039588 +/- 2.64645086 (1.65%) == 'Hbeta_0_sig'
#     Hbeta_0_flx:         31.6367253 +/- 2.59930585 (8.22%) (init = 33.26179)
#     Hbeta_0_cwv:         1.92046534 +/- 1.7159e-05 (0.00%) (init = 1.920458)
#     Hbeta_0_sig:         160.039588 +/- 2.64645085 (1.65%) (init = 166.6124)
#     lbOIIIrb4959_0_flx:  137.783198 +/- 2.79209940 (2.03%) == 'lbOIIIrb5007_0_flx/3.'
#     lbOIIIrb4959_0_cwv:  1.95900570 +/- 1.7503e-05 (0.00%) == '4.960294e-01 / 4.862708e-01 * Hbeta_0_cwv'
#     lbOIIIrb4959_0_sig:  160.039588 +/- 2.64645086 (1.65%) == 'Hbeta_0_sig'
#     lbOIIIrb5007_0_flx:  413.349594 +/- 8.37629818 (2.03%) (init = 405.4918)
#     lbOIIIrb5007_0_cwv:  1.97794019 +/- 1.7672e-05 (0.00%) == '5.008237e-01 / 4.862708e-01 * Hbeta_0_cwv'
#     lbOIIIrb5007_0_sig:  160.039588 +/- 2.64645086 (1.65%) == 'Hbeta_0_sig'
# FITSPEC: Line fit took 0.4 s.
# FIT STATUS: 2

# %% [markdown]
# Plot the results. The resulting plots are saved as `.jpg` files. Data from multiple spaxels are collated into dictionaries containing emission-line and continuum best-fit parameters and saved to various ancillary files.

# %%
q3da(q3di,cols=cols,rows=rows)
#q3da(q3di, quiet=True, noplots=True)
# Out:
# Cube: Negative values encountered in variance array. Taking absolute value.

# %%
qpro = q3dpro.Q3Dpro(q3di, PLATESCALE=0.05, NOCONT=True)

do_kpc = False
saveFile = False
flx = [1e-4,1.]
qsocenter = None
pltarg = {'Ftot':flx,
          'Fci':flx,
          'Sig':[100,850],
          'v50':[-600,600],
          'fluxlog':True,}

#qpro.make_linemap('Hbeta',XYSTYLE=do_kpc,xyCenter=qsocenter,
#                  LINEVAC=False,SAVEDATA=saveFile,VMINMAX=pltarg,PLTNUM=1,CMAP='inferno')
#qpro.make_linemap('[OIII]4959',XYSTYLE=do_kpc,xyCenter=qsocenter,
#                  LINEVAC=False,SAVEDATA=saveFile,VMINMAX=pltarg,PLTNUM=1,CMAP='inferno')
qpro.make_linemap('[OIII]5007',XYSTYLE=do_kpc,xyCenter=qsocenter,
                  LINEVAC=False,SAVEDATA=saveFile,VMINMAX=pltarg,PLTNUM=1,CMAP='inferno')
#qpro.make_linemap('Halpha',XYSTYLE=do_kpc,xyCenter=qsocenter,
#                  LINEVAC=False,SAVEDATA=saveFile,VMINMAX=pltarg,PLTNUM=1,CMAP='inferno')
# Out:
# Plotting emission line maps
